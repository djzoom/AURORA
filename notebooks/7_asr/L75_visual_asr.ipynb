# %% [markdown]
# # 第75课 · 🎨 看见语音变成文字的那条路——波形 → 声谱图 → token 对齐全程可视化
#
# **目标**：看见语音变文字的路——波形 → 谱图 → token 对齐（alignment） / 注意力。
#
# > **🎨**：对齐图与注意力热力图读图指南；可配「这一帧在看哪」的问题。
#
# 🔗 **Aurora 连接**：
# - `aurora.audio.mel` — 将原始波形转换为 mel 频谱，送入 Whisper encoder
# - Whisper encoder 对每帧输出隐状态向量
# - Whisper decoder 的每个输出 token 通过 cross-attention 对这些隐状态加权求和，本节可视化该权重矩阵

# %% [markdown]
# ← **上一课**　[L74 · ASR 错误分析](L74_asr_error_analysis.ipynb)
#
# > 上节课学习了 **ASR 错误分析**：替换/删除/插入模式，从 WER 到可改进方向。
# > 本课将探讨 **ASR 流水线图形化**。

# %% [markdown]
# ## 学习目标
#
# 学完本节，你应该能够：
#
# 1. **说明 CTC 解码规则**，能手工追踪一条给定路径（先去连续重复，再去 blank），并判断它是否解码为目标序列。
# 2. **解读 cross-attention 热力图（heatmap）**，通过对角线清晰程度和注意力熵，判断 Whisper 解码器的对齐质量与幻觉风险。
# 3. **量化对齐质量**，计算注意力权重矩阵的平均熵，并理解熵越高代表 decoder 越不确定当前 token 对应哪些音频帧。

# %% [markdown]
# ## 本节核心直觉
#
# ASR 系统的输出是离散 token 序列，但输入是连续音频帧——这两个序列的长度完全不同，对齐它们是核心难题。
# CTC 加了个 blank 符号，再把所有合法路径的概率加起来，这样不用人工对齐也能训练模型。
# Attention 则在解码时自己决定“当前输出 token 最该关注哪些音频帧”，热力图把这种看不见的对齐画得清清楚楚。

# %%
# Aurora matplotlib bootstrap
from pathlib import Path
import sys

_root = None
_cwd = Path.cwd().resolve()
for _candidate in (_cwd, *_cwd.parents):
    if (_candidate / '_matplotlib_bootstrap.py').exists():
        _root = _candidate
        break
if _root is None:
    _notebooks_dir = _cwd / 'notebooks'
    if _notebooks_dir.exists():
        for _found in _notebooks_dir.rglob('_matplotlib_bootstrap.py'):
            _root = _found.parent
            break
if _root is not None and str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

from _matplotlib_bootstrap import apply as _aurora_mpl_apply
_aurora_mpl_apply()

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

# %% [markdown]
# ## 1. CTC 对齐：多路径 → 同一目标序列
#
# CTC（Connectionist Temporal Classification）在每个时间步输出一个字符（含特殊 blank 符号 `-`）。
# 解码规则：先去掉连续重复，再去掉所有 blank，得到最终序列。
#
# 对于目标词 "HI"，以下路径全部合法：
#
# ```
# 路径示例（T=6, vocab: H I -；下方代码也用 T=6 展示更多路径）
#   H H - I - -   -> 去重 -> H - I - - -> 去blank -> HI  ✓
#   H - I - - -   -> 去重 -> H - I - - -> 去blank -> HI  ✓
#   - H - I - -   -> 去重 -> - H - I - - -> 去blank -> HI ✓
#   H - - I I -   -> 去重 -> H - I -   -> 去blank -> HI   ✓
# ```
# > ⚠️ 注意：路径 `H H I - I` 会解码为 "HII"（两个独立 I），不合法！
# > 紧挨的两个 I 之间需要 blank 隔开才能表示同一个 token 被复用。
#
# CTC loss = `-log( 所有合法路径的概率之和 )`，前向算法在格（lattice）上高效求和。
# 下图用颜色标出所有合法路径经过的节点，帮助你感受“合法路径数”随 T 增长如何爆炸式增加。

# %%
# CTC 合法路径可视化 (静态 lattice 快照)
# 目标序列: 'HI', 时间步 T=6, 词表: {H:0, I:1, -:2(blank)}
# 枚举所有长度为 T 的路径，筛选出解码结果为 'HI' 的合法路径

VOCAB = ['H', 'I', '-']
TARGET = ['H', 'I']
T = 6
V = len(VOCAB)


def ctc_decode(path):
    # CTC decode: 去连续重复 -> 去blank
    collapsed = [path[0]] + [path[i] for i in range(1, len(path)) if path[i] != path[i-1]]
    return [c for c in collapsed if c != '-']


all_paths = list(product(range(V), repeat=T))
valid_paths = [p for p in all_paths if ctc_decode([VOCAB[c] for c in p]) == TARGET]
print(f'总路径数: {V}^{T} = {V**T}')
print(f'合法路径数 (目标="HI"): {len(valid_paths)}')
print(f'前5条合法路径: {[tuple(VOCAB[c] for c in p) for p in valid_paths[:5]]}')

# 绘制 lattice: 节点 (t, v)，合法路径经过的节点用红色标出
node_visited = np.zeros((T, V), dtype=int)
for p in valid_paths:
    for t, v in enumerate(p):
        node_visited[t, v] += 1

fig, ax = plt.subplots(figsize=(9, 3))
for t in range(T):
    for v in range(V):
        count = node_visited[t, v]
        color = plt.cm.Reds(min(count / len(valid_paths) * 3, 1.0)) if count > 0 else '#e0e0e0'
        ax.add_patch(plt.Circle((t, v), 0.35, color=color, zorder=2))
        ax.text(t, v, VOCAB[v], ha='center', va='center', fontsize=10, zorder=3,
                color='white' if count > 0 else '#aaa')

ax.set_xlim(-0.6, T - 0.4)
ax.set_ylim(-0.6, V - 0.4)
ax.set_xticks(range(T))
ax.set_xticklabels([f't={i}' for i in range(T)])
ax.set_yticks(range(V))
ax.set_yticklabels(VOCAB)
ax.set_title(f'CTC Lattice (目标="HI", T={T})\n红色深浅 = 该节点被合法路径经过的频次')
ax.set_aspect('equal')
plt.tight_layout()
plt.show()
print(f'合法路径占比: {len(valid_paths)/V**T*100:.1f}%')
# Out:
# 总路径数: 3^6 = 729
# 合法路径数 (目标="HI"): 70
# 前5条合法路径: [('H', 'H', 'H', 'H', 'H', 'I'), ('H', 'H', 'H', 'H', 'I', 'I'), ('H', 'H', 'H', 'H', 'I', '-'), ('H', 'H', 'H', 'H', '-', 'I'), ('H', 'H', 'H', 'I', 'I', 'I')]
# 合法路径占比: 9.6%

# %% [markdown]
# ### 练习 1：手写 `ctc_decode` 并验证
#
# 不看上方实现，自己写一个 `my_ctc_decode(path)` 函数，使其通过下方测试。
#
# **CTC 规则回顾**：
# 1. 先去掉连续重复字符（不区分是否为 blank）
# 2. 再去掉所有 blank（`'-'`）
# 3. 返回剩余字符列表

# %%
def my_ctc_decode(path):
    """CTC decode a path (list of str tokens) -> list of str.
    Step 1: collapse consecutive duplicates.
    Step 2: remove blanks ('-').
    """
    # TODO: 实现 CTC 解码（约 3 行）
    raise NotImplementedError('请实现 my_ctc_decode')


# ─── 验证 ───────────────────────────────────────────────
try:
    test_cases = [
        (['H', 'H', '-', 'I', '-'],  ['H', 'I']),
        (['H', '-', 'I', '-', '-'],  ['H', 'I']),
        (['-', 'H', '-', 'I', '-'],  ['H', 'I']),
        (['H', '-', '-', 'I', 'I'],  ['H', 'I']),
        (['H', 'H', 'I', '-', 'I'],  ['H', 'I', 'I']),   # 注意：这条解码为 HII，不是 HI
        (['-', '-', '-'],              []),                # 全 blank
        (['A', 'A', 'A'],              ['A']),             # 全重复
    ]
    for path, expected in test_cases:
        result = my_ctc_decode(path)
        assert result == expected, (
            f'路径 {path} → 期望 {expected}，实际 {result}\n'
            f'提示：检查去重顺序和 blank 去除逻辑'
        )
    print('✅ 所有测试通过！my_ctc_decode 实现正确')
except (NotImplementedError, TypeError):
    print('⏳ 请先实现 my_ctc_decode，再运行验证')
# Out:
# ⏳ 请先实现 my_ctc_decode，再运行验证

# %% [markdown]
# ## 2. Cross-Attention 热力图：decoder token 关注哪些音频帧
#
# Whisper 的 decoder 在每个自回归（autoregressive，AR）步骤生成一个 token 时，对 encoder 输出做 cross-attention：
#
# ```
# score(q, k) = q . k / sqrt(d_k)
# alpha = softmax(score)          # shape: (n_tokens, n_frames)
# context = alpha @ encoder_out   # 加权聚合
# ```
#
# `alpha` 矩阵就是热力图的来源——行 = 输出 token，列 = 音频帧，颜色深浅 = 注意力权重（attention weight，alpha）。
# 对齐良好的模型，热力图沿对角线高亮：先发的音素对应早期帧，后发的对应晚期帧。
# 偏离对角线意味着跳帧、重复或幻觉。

# %%
# 模拟 Cross-Attention 热力图 (合成数据)
# 实际使用时替换为 Whisper hook 捕获的真实 attention 权重

rng = np.random.default_rng(42)
N_TOKENS = 10   # 输出 token 数
N_FRAMES = 40   # mel 帧数（窗宽 25ms，hop 10ms，约 100 帧/秒）

token_labels = list('HELLOWORLD')  # 10个字符作为 token 标签 (与 N_TOKENS 对齐)
assert len(token_labels) == N_TOKENS
attn = np.zeros((N_TOKENS, N_FRAMES))
for i in range(N_TOKENS):
    center = int(i / N_TOKENS * N_FRAMES)
    spread = 3
    for j in range(N_FRAMES):
        attn[i, j] = np.exp(-0.5 * ((j - center) / spread) ** 2)
    attn[i] += rng.uniform(0, 0.05, N_FRAMES)
    attn[i] /= attn[i].sum()

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# 左图: 良好对齐 (对角线)
im0 = axes[0].imshow(attn, aspect='auto', cmap='viridis', origin='upper')
axes[0].set_xlabel('编码器帧 (audio frames)')
axes[0].set_ylabel('输出 token')
axes[0].set_yticks(range(N_TOKENS))
axes[0].set_yticklabels(list(token_labels))
axes[0].set_title('Cross-Attention 热力图\n(对角线 = 对齐良好)')
plt.colorbar(im0, ax=axes[0], label='注意力权重')

# 右图: 扰乱对齐 (模拟幻觉/跳帧)
attn_bad = attn.copy()
for i in [3, 4, 7]:
    attn_bad[i] = rng.dirichlet(np.ones(N_FRAMES) * 0.3)
im1 = axes[1].imshow(attn_bad, aspect='auto', cmap='viridis', origin='upper')
axes[1].set_xlabel('编码器帧 (audio frames)')
axes[1].set_ylabel('输出 token')
axes[1].set_yticks(range(N_TOKENS))
axes[1].set_yticklabels(list(token_labels))
axes[1].set_title('Cross-Attention 热力图\n(部分 token 注意力散乱 = 幻觉风险)')
plt.colorbar(im1, ax=axes[1], label='注意力权重')

plt.tight_layout()
plt.show()
print('左图对角线清晰；右图 token 3/4/7 注意力弥散，对应幻觉或跳帧现象')
# Out:
# 左图对角线清晰；右图 token 3/4/7 注意力弥散，对应幻觉或跳帧现象

# %%
# 验证注意力矩阵 shape 和归一化（softmax 输出每行之和应为 1）
assert attn.shape == (N_TOKENS, N_FRAMES), f"注意力矩阵 shape 应为 ({N_TOKENS}, {N_FRAMES})，实际 {attn.shape}"
assert np.allclose(attn.sum(axis=1), 1.0, atol=1e-9), "注意力权重每行之和应为 1（softmax 归一化）"
print(f"✅ Cross-Attention 矩阵验证通过: shape={attn.shape}，每行和为 1.0")
# Out:
# ✅ Cross-Attention 矩阵验证通过: shape=(10, 40)，每行和为 1.0

# %% [markdown]
# ## 参数实验：调整注意力扩散程度，观察热力图变化
#
# 控制参数：
# - `spread`（高斯宽度）：值越大，注意力越扩散；`spread=1` 近乎 hard alignment，`spread=8` 对应模型不确定
# - `noise_level`：注意力背景噪声，模拟低置信度帧
#
# **预期现象**：
# - `spread` 从 1 → 8：对角线变宽 → 模型对当前 token 对应帧的定位越来越模糊
# - `noise_level > 0.15`：背景噪声抬高，热力图整体变灰，对齐结构消失
# - 比较不同 `spread` 下每行熵（entropy，H） `H = -sum(alpha * log(alpha))` 的变化

# %%
# 参数实验: spread & noise_level
rng2 = np.random.default_rng(0)
N_TOKENS2, N_FRAMES2 = 8, 32

def make_attn(spread, noise_level):
    a = np.zeros((N_TOKENS2, N_FRAMES2))
    for i in range(N_TOKENS2):
        center = int(i / N_TOKENS2 * N_FRAMES2)
        for j in range(N_FRAMES2):
            a[i, j] = np.exp(-0.5 * ((j - center) / spread) ** 2)
        a[i] += rng2.uniform(0, noise_level, N_FRAMES2)
        a[i] /= a[i].sum()
    return a

configs = [
    (1,   0.01,  'spread=1, noise=0.01  (hard, 清晰)'),
    (4,   0.05,  'spread=4, noise=0.05  (中等)'),
    (8,   0.15,  'spread=8, noise=0.15  (散乱, 幻觉风险)'),
]

# 缓存结果，确保可视化图与熵打印使用同一份数据（修复 rng2 双消费 bug）
results = [make_attn(sp, nl) for sp, nl, _ in configs]

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
for ax, (sp, nl, title), a in zip(axes, configs, results):
    im = ax.imshow(a, aspect='auto', cmap='plasma', origin='upper')
    ax.set_title(title, fontsize=10)
    ax.set_xlabel('音频帧')
    ax.set_ylabel('输出 token')
    entropies = -np.sum(a * np.log(a + 1e-9), axis=1)
    ax.text(0.98, 0.02, f'平均熵={entropies.mean():.2f}',
            transform=ax.transAxes, ha='right', va='bottom',
            fontsize=8, color='white')
    plt.colorbar(im, ax=ax)

plt.suptitle('参数实验: 注意力扩散程度对热力图的影响', y=1.02)
plt.tight_layout()
plt.show()

for (sp, nl, title), a in zip(configs, results):
    H = -np.sum(a * np.log(a + 1e-9), axis=1).mean()
    print(f'spread={sp:2d}, noise={nl:.2f} -> 平均注意力熵 = {H:.3f}')
print('熵越高说明 decoder 越不确定当前 token 对应哪些帧，是幻觉的预警信号')
# Out:
# spread= 1, noise=0.01 -> 平均注意力熵 = 1.673
# spread= 4, noise=0.05 -> 平均注意力熵 = 2.822
# spread= 8, noise=0.15 -> 平均注意力熵 = 3.232
# 熵越高说明 decoder 越不确定当前 token 对应哪些帧，是幻觉的预警信号

# %% [markdown]
# ## 本课收束
#
# 本节通过 `product(range(V), repeat=T)` 枚举所有路径，并用 `ctc_decode` 过滤出所有合法 CTC 路径，再用 lattice 热力图展示了"多路径 → 同一目标"的核心对齐思想。
# `alpha = softmax(q·k / sqrt(d_k))` 矩阵的可视化揭示了 Whisper decoder cross-attention 的隐式对齐结构，对角线清晰度是幻觉预警的直观指标。
# 两张图都直接对应 `aurora.audio.mel` → encoder → decoder 的推理管道：mel 帧是横轴，token 序列是纵轴。
#
# 下一课：**L76** 音乐理论速成——88 个琴键其实只有 12 个音，从音高、音程到色度轮（chroma）与十二平均律，为音乐特征工程打下根基。

# %%
# ✏️ 本课自评
l75_review = {
    "ctc_decode_impl":         None,  # my_ctc_decode()实现正确，7组测试（含全blank/全重复）通过？True/False
    "ctc_rule_order":          None,  # 记住CTC解码顺序：先去连续重复、再去blank，顺序不能反？True/False
    "lattice_multipath":       None,  # 理解lattice图含义：多条合法路径解码为同一目标序列？True/False
    "attention_heatmap_read":  None,  # 会读cross-attention热力图：对角线清晰=对齐好，弥散=幻觉风险？True/False
    "attention_row_norm":      None,  # 理解softmax归一化：注意力矩阵每行之和=1，熵高=不确定？True/False
}

unfilled = [k for k, v in l75_review.items() if v is None]
assert not unfilled, f'还未填写：{unfilled}'
weak = [k for k, v in l75_review.items() if v is False]
if weak:
    print(f'⚠️  需要加强：{weak}')
else:
    print('✅ L75 全部通关！ASR 模块完成，进入 L76：音乐理论速成')

# %% [markdown]
# ---
#
# → **下一课**　[L76 · 音乐理论速成](../8_music/L76_music_theory.ipynb)
#
# > 下节课将学习 **音乐理论速成**：音高、音程、色度轮与十二平均律。
