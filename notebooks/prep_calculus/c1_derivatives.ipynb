# %% [markdown]
# # 前导·微积分 1 — 导数 = 变化率
#
# **目标**：导数就是"输入动一点，输出动多少"——曲线的斜率。
#
# **为什么对 Aurora 重要**：训练模型 = 看损失对每个权重的导数，再朝让损失变小的方向调。导数是深度学习的全部起点。

# %% [markdown]
# ## 1. 用数值方法近似导数（中心差分）
#
# `f'(x) ≈ (f(x+h) - f(x-h)) / (2h)`，h 取很小的数。

# %%
import numpy as np
f = lambda x: x**2
h = 1e-5
x = 3.0
print('f(x)=x^2 在 x=3 的斜率 ≈', (f(x+h)-f(x-h))/(2*h), ' (真值 2x=6)')

# %% [markdown]
# ## 2. ✏️ 实现 `numeric_derivative(f, x, h=1e-5)`
#
# **提示**：`return (f(x+h) - f(x-h)) / (2*h)`。

# %%
def numeric_derivative(f, x, h=1e-5):
    # ✏️ TODO: 中心差分近似导数
    return None  # ← 改这里

# %%
assert abs(numeric_derivative(lambda x: x**2, 3.0) - 6.0) < 1e-3
assert abs(numeric_derivative(np.sin, 0.0) - 1.0) < 1e-3   # sin'(0)=cos(0)=1
print('✅ 通过：你会数值求导了。')

# %% [markdown]
# ## 3. 记几个常见导数（背下来省事）
#
# | f(x) | f'(x) |
# |---|---|
# | xⁿ | n·xⁿ⁻¹ |
# | eˣ | eˣ |
# | sin x | cos x |
# | ln x | 1/x |

# %% [markdown]
# **🔗 Aurora 连接**：损失曲线的斜率告诉我们"往哪调权重"。下一课把它推广到很多变量 = 梯度。
