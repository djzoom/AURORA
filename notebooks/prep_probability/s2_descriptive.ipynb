# %% [markdown]
# # 前导·概率 2 — 均值、方差与标准化
#
# **目标**：会算均值/方差/标准差，并把数据标准化(z-score)。
#
# **为什么对 Aurora 重要**：训练前几乎都要把特征标准化到"均值0、标准差1"，否则模型很难收敛(这也是 BatchNorm 的直觉)。

# %% [markdown]
# ## 1. 均值、方差、标准差

# %%
import numpy as np
x = np.array([2.0, 4.0, 4.0, 4.0, 5.0, 5.0, 7.0, 9.0])
print('均值 mean :', x.mean())
print('方差 var  :', x.var())
print('标准差 std:', x.std())

# %% [markdown]
# ## 2. ✏️ 实现 z-score 标准化 `zscore(x)`
#
# `(x − 均值) / 标准差`。标准化后均值≈0、标准差≈1。
# **提示**：`return (x - x.mean()) / x.std()`。

# %%
def zscore(x):
    # ✏️ TODO: 返回标准化后的数组
    return None  # ← 改这里

# %%
z = zscore(np.array([2.0, 4.0, 4.0, 4.0, 5.0, 5.0, 7.0, 9.0]))
print('标准化后均值 ≈', round(float(z.mean()), 6), ' 标准差 ≈', round(float(z.std()), 6))
assert abs(z.mean()) < 1e-9 and abs(z.std() - 1.0) < 1e-9
print('✅ 通过：你会标准化特征了。')

# %% [markdown]
# ## 3. 看一眼分布（直方图）

# %%
import matplotlib.pyplot as plt
rng = np.random.default_rng(0)
plt.hist(rng.normal(0, 1, 5000), bins=40)
plt.title('histogram of 5000 samples'); plt.show()

# %% [markdown]
# **🔗 Aurora 连接**：MFCC/mel 特征喂给模型前常做标准化；理解均值方差也是看懂 BatchNorm/LayerNorm 的前提。
